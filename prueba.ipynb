# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import funciones2 as fs2

# %%
#Cargar archivo 
df=fs2.cargar_dataset("Berlin_Alemania.csv")
df
# Out:
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13984 entries, 0 to 13983
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    13984 non-null  int64
#  1   id                                            13984 non-null  int64
#  2   scrape_id                                     13984 non-null  int64
#  3   name                                          13984 non-null  object
#  4   description                                   13365 non-null  object
#  5   host_id                                       13984 non-null  int64
#  6   host_name                                     13975 non-null  object
#  7   host_is_superhost                             13847 non-null  object
#  8   host_listings_count                           13975 non-null  float64
# ...

# %%
#cuenta de valores nulos
fs2.cuenta_valores_nulos(df)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                         0
#  id                                                 0
#  scrape_id                                          0
#  name                                               0
#  description                                      619
#  host_id                                            0
#  host_name                                          9
#  host_is_superhost                                137
#  host_listings_count                                9
#  host_total_listings_count                          9
#  host_has_profile_pic                               9
#  host_identity_verified                             9
#  latitude                                           0
#  longitude                                          0
#  property_type                                      0
#  room_type                                          0
#  accommodates                                       0
# ...

# %%
df["price"] =  df["price"].str.replace(r"[$,]","",regex=True).astype(float)

# %%
#funcion de sustitucion forward fill
fs2.sustitucion_bfill(df, ["description"]) #la funcion sustituye todas las columnas de la lista con el metodo ffill es decir hacia adelante
# Out:
# /Users/jos/Desktop/Profesor alfredo/tarea4/funciones2.py:38: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe[col] = dataframe[col].fillna(method="bfill")
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
# ...

# %%
fs2.sustitucion_bfill(df,["license"]) #la funcion sustituye todas las columnas de la lista con el metodo bfill, es decir hacia atras
# Out:
# /Users/jos/Desktop/Profesor alfredo/tarea4/funciones2.py:38: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe[col] = dataframe[col].fillna(method="bfill")
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
# ...

# %%
fs2.sustitucion_string_concreto(df,["has_availability", "host_is_superhost", "host_has_profile_pic", "host_identity_verified"]) #la funcion sustituye todas las columnas de la lista con el metodo string concreto, en este caso es ideal para las booleanas ya que la respuesta es o True o False
# Out:
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# ...

# %%
fs2.sustitucion_promedio(df,["review_scores_rating", "review_scores_accuracy", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value","price"]) #la funcion sustituye todas las columnas seleccionadas en la lista con el promedio de la columna
# Out:
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# ...

# %%
fs2.sustitucion_mediana(df,["bathrooms","beds","bedrooms"]) #la funcion sustituye todas las columnas de la lista con la mediana
# Out:
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# ...

# %%
fs2.sustitucion_constante(df,["reviews_per_month"]) #la funcion sustituye todas las columnas de la lista con un numero especifico que tiene sentido con la informacion de la columna
# Out:
#        Unnamed: 0                   id       scrape_id  \
# 0               0              2084992  20241221052002
# 1               1  1123383729460847373  20241221052002
# 2               2  1205255838613758737  20241221052002
# 3               3              8164759  20241221052002
# 4               4             18836877  20241221052002
# ...           ...                  ...             ...
# 13979       13979  1066742710842868324  20241221052002
# 13980       13980   882524735229064604  20241221052002
# 13981       13981  1172288594718636022  20241221052002
# 13982       13982  1233927040956879330  20241221052002
# 13983       13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# ...

# %%
df.drop(columns=["Unnamed: 0"])
# Out:
#                         id       scrape_id  \
# 0                  2084992  20241221052002
# 1      1123383729460847373  20241221052002
# 2      1205255838613758737  20241221052002
# 3                  8164759  20241221052002
# 4                 18836877  20241221052002
# ...                    ...             ...
# 13979  1066742710842868324  20241221052002
# 13980   882524735229064604  20241221052002
# 13981  1172288594718636022  20241221052002
# 13982  1233927040956879330  20241221052002
# 13983  1285513092900098347  20241221052002
#
#                                                     name  \
# 0       Nice and cozy apartment in Kreuzberg, Graefekiez
# 1      Furnished room in well equipped serviced apart...
# 2         Luxurous game room with private bath in X-Berg
# 3                           Beautiful single-room studio
# 4                           Unterkunft zentral in Berlin
# ...                                                  ...
# ...

# %%
fs2.cuenta_valores_nulos(df)
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                      0
#  id                                              0
#  scrape_id                                       0
#  name                                            0
#  description                                     0
#  host_id                                         0
#  host_name                                       9
#  host_is_superhost                               0
#  host_listings_count                             9
#  host_total_listings_count                       9
#  host_has_profile_pic                            0
#  host_identity_verified                          0
#  latitude                                        0
#  longitude                                       0
#  property_type                                   0
#  room_type                                       0
#  accommodates                                    0
#  bathrooms                                       0
# ...
